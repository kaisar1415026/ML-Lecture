# %%
myAge = 32
print(myAge)
# Out:
# 32

# %%
myAge = 33
print(myAge)
# Out:
# 33

# %%
print(myAge/3)
# Out:
# 11.0

# %%
myAge = myAge + 1
print(myAge)
# Out:
# 34

# %%
# Challenge
# 1) Create a variable called "restaurantBill" and set its value to 36.17
# 2) Create a variable called "serviceCharge" and set its value to 0.125
# 3) Print out the amount of tip

# %%
type(33)
# Out:
# int

# %%
type(33.6)
# Out:
# float

# %%
type('Philipp')
# Out:
# str

# %%
type(myAge)
# Out:
# int

# %%
type(restaurantBill)
# Out:
# float

# %%
myName = 'Philipp'
type(myName)
# Out:
# str

# %%
firstPrime = 1
secondPrime = 2
thirdPrime = 3

primeNumbers = [3, 7, 61, 29, 199]
type(primeNumbers)
# Out:
# list

# %%
coolPeople = ['Jay Z', 'Ghandi', 'me']
primeAndPeople = ['King Arthur', 17, 11, 'Jennifer Lopez']
type(primeAndPeople)
# Out:
# list

# %%
primeNumbers[2]
# Out:
# 61

# %%
bestPrimeEver = primeNumbers[4]
print(bestPrimeEver)
# Out:
# 199

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
data = pd.read_csv('/content/drive/MyDrive/ML Lecture/Lecture 1/lsd_math_score_data.csv')

# %%
print(data)
# Out:
#    Time_Delay_in_Minutes  LSD_ppm  Avg_Math_Test_Score
# 0                      5     1.17                78.93
# 1                     15     2.97                58.20
# 2                     30     3.26                67.47
# 3                     60     4.69                37.47
# 4                    120     5.83                45.65
# 5                    240     6.00                32.92
# 6                    480     6.41                29.97

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
onlyMathScores = data['Avg_Math_Test_Score']
print(onlyMathScores)
# Out:
# 0    78.93
# 1    58.20
# 2    67.47
# 3    37.47
# 4    45.65
# 5    32.92
# 6    29.97
# Name: Avg_Math_Test_Score, dtype: float64

# %%
data['Test_Subject'] = 'Jennifer Lopez'

# %%
print(data)
# Out:
#    Time_Delay_in_Minutes  LSD_ppm  Avg_Math_Test_Score    Test_Subject
# 0                      5     1.17                78.93  Jennifer Lopez
# 1                     15     2.97                58.20  Jennifer Lopez
# 2                     30     3.26                67.47  Jennifer Lopez
# 3                     60     4.69                37.47  Jennifer Lopez
# 4                    120     5.83                45.65  Jennifer Lopez
# 5                    240     6.00                32.92  Jennifer Lopez
# 6                    480     6.41                29.97  Jennifer Lopez

# %%
data['High_Score'] = 100

# %%
print(data)
# Out:
#    Time_Delay_in_Minutes  LSD_ppm  Avg_Math_Test_Score    Test_Subject  \
# 0                      5     1.17                78.93  Jennifer Lopez
# 1                     15     2.97                58.20  Jennifer Lopez
# 2                     30     3.26                67.47  Jennifer Lopez
# 3                     60     4.69                37.47  Jennifer Lopez
# 4                    120     5.83                45.65  Jennifer Lopez
# 5                    240     6.00                32.92  Jennifer Lopez
# 6                    480     6.41                29.97  Jennifer Lopez
#
#    High_Score
# 0         100
# 1         100
# 2         100
# 3         100
# 4         100
# 5         100
# 6         100

# %%
# Challenge: Overwrite values in rows for High_Score to equal average score + 100
data['High_Score'] = data['High_Score'] + data['Avg_Math_Test_Score']
print(data)
# Out:
#    Time_Delay_in_Minutes  LSD_ppm  Avg_Math_Test_Score    Test_Subject  \
# 0                      5     1.17                78.93  Jennifer Lopez
# 1                     15     2.97                58.20  Jennifer Lopez
# 2                     30     3.26                67.47  Jennifer Lopez
# 3                     60     4.69                37.47  Jennifer Lopez
# 4                    120     5.83                45.65  Jennifer Lopez
# 5                    240     6.00                32.92  Jennifer Lopez
# 6                    480     6.41                29.97  Jennifer Lopez
#
#    High_Score
# 0      178.93
# 1      158.20
# 2      167.47
# 3      137.47
# 4      145.65
# 5      132.92
# 6      129.97

# %%
# Challenge: Square the values stored inside High_Score
data['High_Score'] = data['High_Score'] ** 2
print(data)
# Out:
#    Time_Delay_in_Minutes  LSD_ppm  Avg_Math_Test_Score    Test_Subject  \
# 0                      5     1.17                78.93  Jennifer Lopez
# 1                     15     2.97                58.20  Jennifer Lopez
# 2                     30     3.26                67.47  Jennifer Lopez
# 3                     60     4.69                37.47  Jennifer Lopez
# 4                    120     5.83                45.65  Jennifer Lopez
# 5                    240     6.00                32.92  Jennifer Lopez
# 6                    480     6.41                29.97  Jennifer Lopez
#
#    High_Score
# 0  32015.9449
# 1  25027.2400
# 2  28046.2009
# 3  18898.0009
# 4  21213.9225
# 5  17667.7264
# 6  16892.2009

# %%
type(onlyMathScores)
# Out:
# pandas.core.series.Series

# %%
# Challenge: Create a list called columnList. Put 'LSD_ppm' and 'Avg_Math_Test_Score' inside.
# columnList = ['LSD_ppm', 'Avg_Math_Test_Score']
cleanData = data[['LSD_ppm', 'Avg_Math_Test_Score']]
print(cleanData)
# Out:
#    LSD_ppm  Avg_Math_Test_Score
# 0     1.17                78.93
# 1     2.97                58.20
# 2     3.26                67.47
# 3     4.69                37.47
# 4     5.83                45.65
# 5     6.00                32.92
# 6     6.41                29.97

# %%
type(cleanData)
# Out:
# pandas.core.frame.DataFrame

# %%
y = data[['Avg_Math_Test_Score']]

# %%
type(y)
# Out:
# pandas.core.frame.DataFrame

# %%
# Challenge: 1) Create a variable called X
# Set X equal to the values of LSD_ppm
# Make sure X is a dataframe
# 2) print the value of X
# 3) show the type of X
X = data[['LSD_ppm']]
print(X)
type(X)
# Out:
#    LSD_ppm
# 0     1.17
# 1     2.97
# 2     3.26
# 3     4.69
# 4     5.83
# 5     6.00
# 6     6.41
# pandas.core.frame.DataFrame

# %%
del data['Test_Subject']
print(data)
# Out:
#    Time_Delay_in_Minutes  LSD_ppm  Avg_Math_Test_Score  High_Score
# 0                      5     1.17                78.93  32015.9449
# 1                     15     2.97                58.20  25027.2400
# 2                     30     3.26                67.47  28046.2009
# 3                     60     4.69                37.47  18898.0009
# 4                    120     5.83                45.65  21213.9225
# 5                    240     6.00                32.92  17667.7264
# 6                    480     6.41                29.97  16892.2009

# %%
# Challenge: Delete High_Score column from data
del data['High_Score']
print(data)
# Out:
#    Time_Delay_in_Minutes  LSD_ppm  Avg_Math_Test_Score
# 0                      5     1.17                78.93
# 1                     15     2.97                58.20
# 2                     30     3.26                67.47
# 3                     60     4.69                37.47
# 4                    120     5.83                45.65
# 5                    240     6.00                32.92
# 6                    480     6.41                29.97

# %% [markdown]
# ### Example
#
# Let's walk through a very simple example using two numpy arrays. You can also use lists, but most likely you'll be passing numpy arrays or pandas columns (which essentially also behave like arrays).
#
# ** The data we want to plot:**
#
# np.linspace(start, stop, num)
#
# The step size is given by $\frac{\text{stop} - \text{start}}{\text{num} - 1}$.

# %%
import numpy as np
x = np.linspace(0, 5, 11)
y = x ** 2

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %% [markdown]
# ## Basic Matplotlib Commands
#
# We can create a very simple line plot using the following ( I encourage you to pause and use Shift+Tab along the way to check out the document strings for the functions we are using).

# %%
plt.plot(x, y, 'r') # 'r' is the color red
plt.xlabel('X Axis Title Here')
plt.ylabel('Y Axis Title Here')
plt.title('String Title Here')
plt.show()

# %%
# plt.subplot(nrows, ncols, plot_number)
plt.subplot(1,2,1)
plt.plot(x, y, 'r--') # More on color options later
plt.subplot(1,2,2)
plt.plot(y, x, 'g*-');

# %%
import cv2

# %%
img1=cv2.imread('/content/drive/MyDrive/ML Lecture/Lecture 1/front1.jpg')
img2=cv2.imread('/content/drive/MyDrive/ML Lecture/Lecture 1/front2.jpg')

# %%
fig=plt.figure(figsize=(20,15))
fig.add_subplot(1,2,1),plt.imshow(img1,cmap='gray'),plt.title('Frnt1 Image');
fig.add_subplot(1,2,2),plt.imshow(img2,cmap='gray'),plt.title('Front2 image');

# %% [markdown]
# # Distribution Plots
#
# Let's discuss some plots that allow us to visualize the distribution of a data set. These plots are:
#
# ## Imports

# %%
import seaborn as sns

# %% [markdown]
# ## Data
# Seaborn comes with built-in data sets!

# %%
tips = sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ## distplot
#
# The distplot shows the distribution of a univariate set of observations.

# %%
sns.distplot(tips['total_bill'])
# Out:
# /tmp/ipython-input-4271412032.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tips['total_bill'])
# <Axes: xlabel='total_bill', ylabel='Density'>

# %% [markdown]
# To remove the kde layer and just have the histogram use:

# %%
sns.distplot(tips['total_bill'],kde=False,bins=30)
# Out:
# /tmp/ipython-input-1274391954.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tips['total_bill'],kde=False,bins=30)
# <Axes: xlabel='total_bill'>

# %% [markdown]
# Most of the bills happens between 10 and 20 dolloars.

# %% [markdown]
# ## jointplot
#
# jointplot() allows you to basically match up two distplots for bivariate data. With your choice of what **kind** parameter to compare with:
# * “scatter”
# * “reg”
# * “resid”
# * “kde”
# * “hex”

# %%
sns.jointplot(x='total_bill',y='tip',data=tips,kind='scatter')

# %% [markdown]
# You can see the tip on the y axis and total bill along the x axis and then zoom out so you can see the whole plot. And then in between I have a scatterplot and this scatterplot actually basically makes sense because it looks like it has a trend that as you go higher in total bill you will go higher in tip and that makes sense because tips are usually proportionate to your total bill.

# %%
sns.jointplot(x='total_bill',y='tip',data=tips,kind='hex')

# %% [markdown]
# It's similar to scatter except basically if the hexagon has a certain number of points in it it gets darker and if it has less points it gets lighter.

# %%
sns.jointplot(x='total_bill',y='tip',data=tips,kind='reg')

# %% [markdown]
# This is just showing almost like a linear fit to the scattered point data and you can actually see it has a P value in a Peerson coefficient which we will discuss later on when we actually discuss linear regression.

# %% [markdown]
# ## Pairplot
#
# pairplot will plot pairwise relationships across an entire dataframe (for the numerical columns) and supports a color hue argument (for categorical columns).

# %%
sns.pairplot(tips)

# %% [markdown]
# Here we basically have a pair plot for all the numerical column values. So we have size vs. total bill size vs. tip. And then when you get to a parameter versus itself for instance size versus size instead of actually doing a scatterplot which when it makes sense you just have a straight line. You see a histogram instead. And same thing for Tip versus tip. And for total bill versus total bill that means per plot is a really nice way to quickly visualize your data.

# %%
# ======================================
# Dummy Supervised Learning Example
# (scikit-learn | Google Colab)
# ======================================

# Step 1: Import required libraries
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split
##from sklearn.family import model
from sklearn.linear_model import LinearRegression


# Step 2: Create dummy data (features X and labels y)
# X = features, y = target
X = np.array([[1], [2], [3], [4], [5], [6], [7], [8]])
y = np.array([3, 5, 7, 9, 11, 13, 15, 17])  # y = 2x + 1


# Step 3: Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.25,
    random_state=42
)


# Step 4: Import and instantiate the model
model = LinearRegression()


# Step 5: Train (fit) the model on training data
model.fit(X_train, y_train)


# Step 6: Make predictions on the test data
y_pred = model.predict(X_test)


# Step 7: Print results
print("X_test:")
print(X_test)

print("\nActual y values:")
print(y_test)

print("\nPredicted y values:")
print(y_pred)


# Step 8: Inspect learned parameters
print("\nModel coefficient (slope):", model.coef_)
print("Model intercept:", model.intercept_)
# Out:
# X_test:
# [[2]
#  [6]]
#
# Actual y values:
# [ 5 13]
#
# Predicted y values:
# [ 5. 13.]
#
# Model coefficient (slope): [2.]
# Model intercept: 1.0
